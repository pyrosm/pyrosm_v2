# %%
from pyrosm import OSM, get_data

osm = OSM(get_data("test_pbf"))

# %%
# Read the Raw OSM data elements
osm._read_pbf()

# %%
# Check the raw data attributes
osm._nodes
# Out:
# {'id': array([    246991,     246993,     246994, ..., 6270887034, 6270887035,
#         6270887036]),
#  'changeset': array([0, 0, 0, ..., 0, 0, 0], dtype=int32),
#  'lon': array([26.960917, 26.96345 , 26.965702, ..., 26.969236, 26.965849,
#         26.960424], dtype=float32),
#  'visible': array([False, False, False, ..., False, False, False], dtype=object),
#  'version': array([4, 4, 3, ..., 2, 2, 2], dtype=int32),
#  'timestamp': array([1296224043, 1296224034, 1255133941, ..., 1550928214, 1550928215,
#         1550928215], dtype=uint32),
#  'tags': array([None, None, None, ...,
#         {'direction': '338', 'fixme': 'Position_estimated', 'highway': 'bus_stop', 'name': 'Hiidenkirnuntie P', 'name:fi': 'Hiidenkirnuntie P', 'note': 'LISATIEDOT:0', 'ref:findr': '155640', 'shelter': 'no', 'source': 'Digiroad.fi'},
# ...

# %%
# Check node coordinate hashmap
#osm._node_coordinates

# %%
# See the first way element
osm._way_records[0]
# Out:
# {'id': 2288572,
#  'version': 14,
#  'timestamp': 1414871170,
#  'visible': False,
#  'nodes': [372554297,
#   527715622,
#   246996,
#   478556875,
#   527715624,
#   246997,
#   246998,
#   247000,
#   1124866935,
#   527715631,
#   246999,
#   247001,
#   247003,
#   527715635,
#   247004,
#   247005,
#   2023337184],
#  'ref': '7;15',
#  'oneway': 'yes',
#  'highway': 'motorway',
#  'int_ref': 'E 18'}

# %%
# See the first relation
osm._relations
# Out:
# {'id': array([  32694,  352283, 2617378, 5307012, 8486578]),
#  'changeset': array([0, 0, 0, 0, 0], dtype=int32),
#  'members': array([{'member_id': array([ 17738482, 314651679, 314651677, 314651678, 425611204, 186129265,
#                425611205, 186129266, 185510726, 394289980, 185510725, 114676912,
#                259481814, 239534552, 114676906,  25406715,  25406716,  25406717,
#                425611252,  25912217,  87158761, 425611284, 185509259,  25968538,
#                425611212, 394289947, 480579754, 480579756,  25968537, 185508694,
#                 25968542, 185508695, 219749817, 219749815, 383574825, 185508696,
#                479982466, 488509283, 488509284, 111504812,   4484722, 383574820,
#                383574821,   4482886, 383574819, 565118859, 565104102, 185507650,
#                 23259342,  25777886, 136019928, 183855718, 183855717, 232003510,
#                232003509,  37431339,  37431341,  32762351, 135309183,  27092357,
# ...
